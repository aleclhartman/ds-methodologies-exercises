# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from wrangle import wrangle_telco

# %%
df = wrangle_telco()
df
# Out:
#      customer_id  monthly_charges  tenure  total_charges
# 0     0013-SMEOE           109.70      71        7904.25
# 1     0014-BMAQU            84.65      63        5377.80
# 2     0016-QLJIS            90.45      65        5957.90
# 3     0017-DINOC            45.20      54        2460.55
# 4     0017-IUDMW           116.80      72        8456.75
# ...          ...              ...     ...            ...
# 1690  9964-WBQDJ            24.40      71        1725.40
# 1691  9972-EWRJS            19.25      67        1372.90
# 1692  9975-GPKZU            19.75      46         856.50
# 1693  9993-LHIEB            67.85      67        4627.65
# 1694  9995-HOTOH            59.00      63        3707.60
#
# [1685 rows x 4 columns]

# %% [markdown]
# >The fundamental business question initally asked will be your lens through which you will view your data. It is your framework.

# %%
# quick and dirty
df.hist()
plt.show()

# %%
sns.distplot(df["monthly_charges"])
plt.show()

# %% [markdown]
# > Line in a distplot give the probability of the value in the x axis occurring

# %%
sns.distplot(df["tenure"])
plt.show()

# %%
sns.distplot(df["total_charges"])
plt.show()

# %%
df.corr()
# Out:
#                  monthly_charges    tenure  total_charges
# monthly_charges         1.000000  0.414049       0.945267
# tenure                  0.414049  1.000000       0.631207
# total_charges           0.945267  0.631207       1.000000

# %% [markdown]
# ## Findings so far... (as a habit, write down what you learn when you learn it)
# - monthly_charges has the highest correlation coefficient with total_charges

# %%
sns.pairplot(df, kind="reg")
plt.show()

# %%
sns.lmplot("total_charges", "monthly_charges", df)
plt.show()

# %%
sns.jointplot("total_charges", "monthly_charges", df)
plt.show()
