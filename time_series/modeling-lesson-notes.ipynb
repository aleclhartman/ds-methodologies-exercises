# %% [markdown]
# # Forecasting

# %% [markdown]
# ## Methods

# %% [markdown]
# - Last Observed Value
# - Simple Average
# - Moving Average
# - Holt's Linear Trend
# - Previous Cycle
#
# **Tomorrow**
# - FB Prophet
#
# **Appendix (or Google)**
# - ARIMA (ARIMAX)
# - Holt Winters
# - Exponential Smoothing

# %% [markdown]
# ---
# - Objetive: Build forecasting models to predict number of items sold and total dollars sold.

# %% [markdown]
# ## Wrangle

# %%
import numpy as np
import pandas as pd

from datetime import datetime

from sklearn.metrics import mean_squared_error

from math import sqrt

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import statsmodels.api as sm
from statsmodels.tsa.api import Holt

import acquire as ac
import prepare as pr

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Acquire

# %%
df = ac.get_sales()
df.head()
# Out:
#    sale_amount                      sale_date  sale_id item_brand  item_id  \
# 0         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1   Riceland        1
# 1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2   Riceland        1
# 2         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3   Riceland        1
# 3         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4   Riceland        1
# 4         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5   Riceland        1
#
#                         item_name  item_price   item_upc12   item_upc14  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 1  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 2  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 3  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 4  Riceland American Jazmine Rice        0.84  35200264013  35200264013
#
#             store_address   store_city  store_id store_state  store_zipcode
# 0  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 1  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 2  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 3  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 4  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253

# %% [markdown]
# ### Prepare

# %%
df = df.assign(ds = pd.to_datetime(df.sale_date)).sort_values("ds")\
    .assign(dollars_sold = df.sale_amount * df.item_price)\
    .assign(items_sold = df.sale_amount)\
    .groupby(["ds"])[["dollars_sold", "items_sold"]].sum()\
    .reset_index().set_index("ds")

# %% [markdown]
# ## Split

# %%
df
# Out:
#                            dollars_sold  items_sold
# ds
# 2013-01-01 00:00:00+00:00      73844.01     13696.0
# 2013-01-02 00:00:00+00:00      73570.58     13678.0
# 2013-01-03 00:00:00+00:00      78169.48     14488.0
# 2013-01-04 00:00:00+00:00      84467.73     15677.0
# 2013-01-05 00:00:00+00:00      87621.85     16237.0
# ...                                 ...         ...
# 2017-12-27 00:00:00+00:00     109151.15     20378.0
# 2017-12-28 00:00:00+00:00     117377.49     21885.0
# 2017-12-29 00:00:00+00:00     126541.84     23535.0
# 2017-12-30 00:00:00+00:00     134903.07     24988.0
# 2017-12-31 00:00:00+00:00     140905.74     26420.0
#
# [1826 rows x 2 columns]

# %%
train_size = round(int(len(df)) * .66)
test_size = int(len(df) - train_size)

train = df[:train_size]
test = df[train_size:]

train
# Out:
#                            dollars_sold  items_sold
# ds
# 2013-01-01 00:00:00+00:00      73844.01     13696.0
# 2013-01-02 00:00:00+00:00      73570.58     13678.0
# 2013-01-03 00:00:00+00:00      78169.48     14488.0
# 2013-01-04 00:00:00+00:00      84467.73     15677.0
# 2013-01-05 00:00:00+00:00      87621.85     16237.0
# ...                                 ...         ...
# 2016-04-15 00:00:00+00:00     170008.40     31445.0
# 2016-04-16 00:00:00+00:00     178538.37     33306.0
# 2016-04-17 00:00:00+00:00     191367.09     35747.0
# 2016-04-18 00:00:00+00:00     126953.52     23660.0
# 2016-04-19 00:00:00+00:00     149645.67     27752.0
#
# [1205 rows x 2 columns]

# %%
test
# Out:
#                            dollars_sold  items_sold
# ds
# 2016-04-20 00:00:00+00:00     148032.83     27627.0
# 2016-04-21 00:00:00+00:00     158310.20     29403.0
# 2016-04-22 00:00:00+00:00     170256.17     31583.0
# 2016-04-23 00:00:00+00:00     178714.14     33316.0
# 2016-04-24 00:00:00+00:00     191863.49     35576.0
# ...                                 ...         ...
# 2017-12-27 00:00:00+00:00     109151.15     20378.0
# 2017-12-28 00:00:00+00:00     117377.49     21885.0
# 2017-12-29 00:00:00+00:00     126541.84     23535.0
# 2017-12-30 00:00:00+00:00     134903.07     24988.0
# 2017-12-31 00:00:00+00:00     140905.74     26420.0
#
# [621 rows x 2 columns]

# %% [markdown]
# **Verify Splits**

# %%
print(len(train) + len(test) == len(df))
print(df.head(1) == train.head(1))
# Out:
# True
#                            dollars_sold  items_sold
# ds
# 2013-01-01 00:00:00+00:00          True        True

# %% [markdown]
# ## Forecasting
# ---
# ### Last Observed Value
# **Make Predictions**

# %%
# items sold
items = train["items_sold"][-1:][0]
items
# Out:
# 27752.0

# %%
# dollars
dollars = round(train["dollars_sold"][-1:][0], 2)
dollars
# Out:
# 149645.67

# %%
yhat_df = pd.DataFrame({
    "items_sold": [items],
    "dollars_sold": [dollars]
}, index=test.index)

yhat_df.head()
# Out:
#                            items_sold  dollars_sold
# ds
# 2016-04-20 00:00:00+00:00     27752.0     149645.67
# 2016-04-21 00:00:00+00:00     27752.0     149645.67
# 2016-04-22 00:00:00+00:00     27752.0     149645.67
# 2016-04-23 00:00:00+00:00     27752.0     149645.67
# 2016-04-24 00:00:00+00:00     27752.0     149645.67

# %% [markdown]
# **Plot Actual vs. Predicted Values**

# %%
for col in train.columns:
    plt.figure(figsize=(16, 4))
    plt.plot(train[col], label="Train", linewidth=1)
    plt.plot(test[col], label="Test", linewidth=1)
    plt.plot(yhat_df[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# **Evaluate**
#
# Compute RMSE

# %%
for col in train.columns:
    print(f"{col} = {round(sqrt(mean_squared_error(test[col], yhat_df[col])))}")
# Out:
# dollars_sold = 34906
# items_sold = 6521

# %%
eval_df = pd.DataFrame(columns = ["model_type", "target_var", "rmse"])

# %%
def evaluate(target_var):
    rmse = round(sqrt(mean_squared_error(test[target_var], yhat_df[target_var])))
    return rmse

# %%
def plot_and_eval(target_var):
    plt.figure(figsize=(16, 4))
    plt.plot(train[target_var], label="Train", linewidth=1)
    plt.plot(test[target_var], label="Test", linewidth=1)
    plt.plot(yhat_df[target_var])
    plt.title(target_var)
    rmse = evaluate(target_var)
    print(target_var, f"-- RMSE: {rmse:.0f}")
    plt.show()

# %%
plot_and_eval("items_sold")
# Out:
# items_sold -- RMSE: 6521

# %%
eval_df.head()
# Out:
# Empty DataFrame
# Columns: [model_type, target_var, rmse]
# Index: []

# %%
# function to store eval rmse for each model
def append_rmse(model_type, target_var):
    rmse = evaluate(target_var)
    d = {"model_type": [model_type], "target_var": [target_var], "rmse": rmse}
    d = pd.DataFrame(d)
    return eval_df.append(d, ignore_index=True)

# %%
eval_df = append_rmse("Last Observed Value", target_var="items_sold")
eval_df = append_rmse("Last Observed Value", target_var="dollars_sold")
eval_df
# Out:
#             model_type    target_var   rmse
# 0  Last Observed Value    items_sold   6521
# 1  Last Observed Value  dollars_sold  34906

# %% [markdown]
# ---
# ### Simple Average

# %%
items = round(train["items_sold"].mean(), 2)
dollars = round(train["dollars_sold"].mean(), 2)

yhat_df = pd.DataFrame({
    "items_sold": items, 
    "dollars_sold": dollars,
}, index=test.index)

# %%
yhat_df.head()
# Out:
#                            items_sold  dollars_sold
# ds
# 2016-04-20 00:00:00+00:00     24225.7     130250.37
# 2016-04-21 00:00:00+00:00     24225.7     130250.37
# 2016-04-22 00:00:00+00:00     24225.7     130250.37
# 2016-04-23 00:00:00+00:00     24225.7     130250.37
# 2016-04-24 00:00:00+00:00     24225.7     130250.37

# %% [markdown]
# **Plot**

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# dollars_sold -- RMSE: 44784
# items_sold -- RMSE: 8336

# %% [markdown]
# **Evaluate**

# %%
for col in train.columns:
    eval_df = append_rmse(model_type="Simple Average", target_var=col)
    
eval_df
# Out:
#             model_type    target_var   rmse
# 0  Last Observed Value    items_sold   6521
# 1  Last Observed Value  dollars_sold  34906
# 2       Simple Average  dollars_sold  44784
# 3       Simple Average    items_sold   8336

# %% [markdown]
# ---
# ### Moving Average

# %%
period = 30 # for our data that's 30 days

items = round(train["items_sold"].rolling(period).mean().iloc[-1], 2)

dollars = round(train["dollars_sold"].rolling(period).mean().iloc[-1], 2)

# %%
def make_predictions():
    yhat_df = pd.DataFrame({
        "items_sold": items, 
        "dollars_sold": dollars,
    }, index=test.index)
    return yhat_df

# %%
yhat_df = make_predictions()

# %%
yhat_df
# Out:
#                            items_sold  dollars_sold
# ds
# 2016-04-20 00:00:00+00:00    28085.43      151035.0
# 2016-04-21 00:00:00+00:00    28085.43      151035.0
# 2016-04-22 00:00:00+00:00    28085.43      151035.0
# 2016-04-23 00:00:00+00:00    28085.43      151035.0
# 2016-04-24 00:00:00+00:00    28085.43      151035.0
# ...                               ...           ...
# 2017-12-27 00:00:00+00:00    28085.43      151035.0
# 2017-12-28 00:00:00+00:00    28085.43      151035.0
# 2017-12-29 00:00:00+00:00    28085.43      151035.0
# 2017-12-30 00:00:00+00:00    28085.43      151035.0
# 2017-12-31 00:00:00+00:00    28085.43      151035.0
#
# [621 rows x 2 columns]

# %% [markdown]
# **Plot**

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# dollars_sold -- RMSE: 34510
# items_sold -- RMSE: 6424

# %% [markdown]
# **Evaluate**

# %%
for col in train.columns:
    eval_df = append_rmse("30-Day Rolling Avg.", col)

# %%
eval_df
# Out:
#             model_type    target_var   rmse
# 0  Last Observed Value    items_sold   6521
# 1  Last Observed Value  dollars_sold  34906
# 2       Simple Average  dollars_sold  44784
# 3       Simple Average    items_sold   8336
# 4  30-Day Rolling Avg.  dollars_sold  34510
# 5  30-Day Rolling Avg.    items_sold   6424

# %% [markdown]
# ---
# ### Holt's Linear Trend
# **Exponential Smoothing**: a way to apply weight as time elaspes depending on recency.
#
# - $\alpha$ / smoothing_level: smoothing parameter for mean
#     - Values closer to
# - $\beta$ / smoothing_slope: smoothing parameter for the slope

# %%
sm.tsa.seasonal_decompose(train["items_sold"].resample("W").mean()).\
    plot()
plt.show()

# %% [markdown]
# **Make predictions**

# %% [markdown]
# Holt:
# - exponentional = True/False

# %%
for col in train.columns:
    # create model object
    model = Holt(train[col], exponential=True)

    # fit the object
    model = model.fit(smoothing_level=.28, smoothing_slope=.1, optimized=False)

    # use the object
    yhat = model.predict(start=test.index[0], end=test.index[-1])

    yhat_df[col] = round(yhat, 2)

# %%
yhat_df
# Out:
#                            items_sold  dollars_sold
# ds
# 2016-04-20 00:00:00+00:00    29762.17     160062.74
# 2016-04-21 00:00:00+00:00    29798.84     160249.53
# 2016-04-22 00:00:00+00:00    29835.55     160436.53
# 2016-04-23 00:00:00+00:00    29872.31     160623.75
# 2016-04-24 00:00:00+00:00    29909.11     160811.19
# ...                               ...           ...
# 2017-12-27 00:00:00+00:00    63541.06     328319.35
# 2017-12-28 00:00:00+00:00    63619.34     328702.49
# 2017-12-29 00:00:00+00:00    63697.72     329086.06
# 2017-12-30 00:00:00+00:00    63776.20     329470.09
# 2017-12-31 00:00:00+00:00    63854.77     329854.57
#
# [621 rows x 2 columns]

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# dollars_sold -- RMSE: 96189
# items_sold -- RMSE: 19033

# %%
for col in train.columns:
    eval_df = append_rmse("Holt's", col)
    
eval_df
# Out:
#             model_type    target_var   rmse
# 0  Last Observed Value    items_sold   6521
# 1  Last Observed Value  dollars_sold  34906
# 2       Simple Average  dollars_sold  44784
# 3       Simple Average    items_sold   8336
# 4  30-Day Rolling Avg.  dollars_sold  34510
# 5  30-Day Rolling Avg.    items_sold   6424
# 6               Holt's  dollars_sold  96189
# 7               Holt's    items_sold  19033

# %% [markdown]
# ---
# ### Previous Cycle

# %%
train.head()
# Out:
#                            dollars_sold  items_sold
# ds
# 2013-01-01 00:00:00+00:00      73844.01     13696.0
# 2013-01-02 00:00:00+00:00      73570.58     13678.0
# 2013-01-03 00:00:00+00:00      78169.48     14488.0
# 2013-01-04 00:00:00+00:00      84467.73     15677.0
# 2013-01-05 00:00:00+00:00      87621.85     16237.0

# %%
train.tail()
# Out:
#                            dollars_sold  items_sold
# ds
# 2016-04-15 00:00:00+00:00     170008.40     31445.0
# 2016-04-16 00:00:00+00:00     178538.37     33306.0
# 2016-04-17 00:00:00+00:00     191367.09     35747.0
# 2016-04-18 00:00:00+00:00     126953.52     23660.0
# 2016-04-19 00:00:00+00:00     149645.67     27752.0

# %%
yhat_df = train["2015-04-20":"2016-04-19"] + train["2013-04-20":"2016-04-19"].diff(365).mean()

# set the date (index) to be represent the date for our predictions
yhat_df.index = pd.date_range('2016-04-20', periods=len(yhat_df))

# %%
yhat_df.head()
# Out:
#              dollars_sold    items_sold
# 2016-04-20  127466.343981  23723.562244
# 2016-04-21  146053.833981  27273.562244
# 2016-04-22  147652.923981  27489.562244
# 2016-04-23  158910.253981  29421.562244
# 2016-04-24  166832.293981  31045.562244

# %%
# for col in train.columns:
#     plot_and_eval(col)
