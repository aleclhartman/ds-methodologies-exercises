# %% [markdown]
# # Prepare

# %%
import numpy as np
import pandas as pd
from datetime import timedelta, datetime

import matplotlib.pyplot as plt
# %matplotlib inline

import acquire as ac
import prepare as pr

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Acquire

# %%
sales = ac.get_sales()
sales
# Out:
#         sale_amount                      sale_date  sale_id item_brand  \
# 0              13.0  Tue, 01 Jan 2013 00:00:00 GMT        1   Riceland
# 1              11.0  Wed, 02 Jan 2013 00:00:00 GMT        2   Riceland
# 2              14.0  Thu, 03 Jan 2013 00:00:00 GMT        3   Riceland
# 3              13.0  Fri, 04 Jan 2013 00:00:00 GMT        4   Riceland
# 4              10.0  Sat, 05 Jan 2013 00:00:00 GMT        5   Riceland
# ...             ...                            ...      ...        ...
# 912995         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     Choice
# 912996         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     Choice
# 912997         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     Choice
# 912998         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     Choice
# 912999         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     Choice
#
#         item_id                                          item_name  \
# 0             1                     Riceland American Jazmine Rice
# 1             1                     Riceland American Jazmine Rice
# 2             1                     Riceland American Jazmine Rice
# 3             1                     Riceland American Jazmine Rice
# 4             1                     Riceland American Jazmine Rice
# ...         ...                                                ...
# 912995       50  Choice Organic Teas Black Tea Classic Black - ...
# 912996       50  Choice Organic Teas Black Tea Classic Black - ...
# 912997       50  Choice Organic Teas Black Tea Classic Black - ...
# 912998       50  Choice Organic Teas Black Tea Classic Black - ...
# 912999       50  Choice Organic Teas Black Tea Classic Black - ...
#
#         item_price   item_upc12   item_upc14           store_address  \
# 0             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 1             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 2             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 3             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 4             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# ...            ...          ...          ...                     ...
# 912995        5.20  47445919221  47445919221    8503 NW Military Hwy
# 912996        5.20  47445919221  47445919221    8503 NW Military Hwy
# 912997        5.20  47445919221  47445919221    8503 NW Military Hwy
# 912998        5.20  47445919221  47445919221    8503 NW Military Hwy
# 912999        5.20  47445919221  47445919221    8503 NW Military Hwy
#
#          store_city  store_id store_state  store_zipcode
# 0       San Antonio         1          TX          78253
# 1       San Antonio         1          TX          78253
# 2       San Antonio         1          TX          78253
# 3       San Antonio         1          TX          78253
# 4       San Antonio         1          TX          78253
# ...             ...       ...         ...            ...
# 912995  San Antonio        10          TX          78231
# 912996  San Antonio        10          TX          78231
# 912997  San Antonio        10          TX          78231
# 912998  San Antonio        10          TX          78231
# 912999  San Antonio        10          TX          78231
#
# [913000 rows x 14 columns]

# %% [markdown]
# ---
# # Exercises
# Using your store items data you acquired in lesson 1 exercises:

# %% [markdown]
# ---
# ## 1. Convert date column to datetime format.

# %%
sales["sale_date"] = pd.to_datetime(sales["sale_date"], format='%a, %d %b %Y %H:%M:%S %Z')
sales.head()
# Out:
#    sale_amount                 sale_date  sale_id item_brand  item_id  \
# 0         13.0 2013-01-01 00:00:00+00:00        1   Riceland        1
# 1         11.0 2013-01-02 00:00:00+00:00        2   Riceland        1
# 2         14.0 2013-01-03 00:00:00+00:00        3   Riceland        1
# 3         13.0 2013-01-04 00:00:00+00:00        4   Riceland        1
# 4         10.0 2013-01-05 00:00:00+00:00        5   Riceland        1
#
#                         item_name  item_price   item_upc12   item_upc14  \
# 0  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 1  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 2  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 3  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 4  Riceland American Jazmine Rice        0.84  35200264013  35200264013
#
#             store_address   store_city  store_id store_state  store_zipcode
# 0  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 1  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 2  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 3  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 4  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253

# %% [markdown]
# ---
# ## 2. Plot the distribution of `sale_amount` and `item_price`.

# %%
plt.figure(figsize=(16, 8))

sales.sale_amount.hist()
plt.title("Distribution of Sale Amount")
plt.show()

# %%
plt.figure(figsize=(16, 8))

sales.item_price.hist()
plt.title("Distribution of Item Price")
plt.show()

# %% [markdown]
# ---
# ## 3. Set the index to be the datetime variable.

# %%
sales = sales.sort_values("sale_date").set_index("sale_date")
sales
# Out:
#                            sale_amount  sale_id       item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1         Riceland        1
# 2013-01-01 00:00:00+00:00         26.0   211817          Mueller       12
# 2013-01-01 00:00:00+00:00         27.0   832657       Mama Marys       46
# 2013-01-01 00:00:00+00:00         54.0   213643          Mueller       12
# 2013-01-01 00:00:00+00:00         35.0   215469          Mueller       12
# ...                                ...      ...              ...      ...
# 2017-12-31 00:00:00+00:00         21.0   619014            Halls       34
# 2017-12-31 00:00:00+00:00         32.0   620840            Halls       34
# 2017-12-31 00:00:00+00:00         55.0   622666      Natures Way       35
# 2017-12-31 00:00:00+00:00        100.0   598928  The First Years       33
# 2017-12-31 00:00:00+00:00         82.0   913000           Choice       50
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# ...                                                                      ...
# 2017-12-31 00:00:00+00:00  Halls Menthol Cough Suppresant/oral Anesthetic...
# 2017-12-31 00:00:00+00:00  Halls Menthol Cough Suppresant/oral Anesthetic...
# 2017-12-31 00:00:00+00:00                     Natures Way Forskohlii - 60 Ct
# 2017-12-31 00:00:00+00:00  Tomy The First Years Gumdrop Orthodontic Pacif...
# 2017-12-31 00:00:00+00:00  Choice Organic Teas Black Tea Classic Black - ...
#
#                            item_price    item_upc12    item_upc14  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84   35200264013   35200264013
# 2013-01-01 00:00:00+00:00        8.40   74676640211   74676640211
# 2013-01-01 00:00:00+00:00        4.65   35457770664   35457770664
# 2013-01-01 00:00:00+00:00        8.40   74676640211   74676640211
# 2013-01-01 00:00:00+00:00        8.40   74676640211   74676640211
# ...                               ...           ...           ...
# 2017-12-31 00:00:00+00:00        4.17  312546628694  312546628694
# 2017-12-31 00:00:00+00:00        4.17  312546628694  312546628694
# 2017-12-31 00:00:00+00:00        5.19   33674100066   33674100066
# 2017-12-31 00:00:00+00:00        6.52   71463060078   71463060078
# 2017-12-31 00:00:00+00:00        5.20   47445919221   47445919221
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio         8
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio         9
# ...                                           ...          ...       ...
# 2017-12-31 00:00:00+00:00      735 SW Military Dr  San Antonio         9
# 2017-12-31 00:00:00+00:00    8503 NW Military Hwy  San Antonio        10
# 2017-12-31 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2017-12-31 00:00:00+00:00     15000 San Pedro Ave  San Antonio         8
# 2017-12-31 00:00:00+00:00    8503 NW Military Hwy  San Antonio        10
#
#                           store_state  store_zipcode
# sale_date
# 2013-01-01 00:00:00+00:00          TX          78253
# 2013-01-01 00:00:00+00:00          TX          78217
# 2013-01-01 00:00:00+00:00          TX          78217
# 2013-01-01 00:00:00+00:00          TX          78232
# 2013-01-01 00:00:00+00:00          TX          78221
# ...                               ...            ...
# 2017-12-31 00:00:00+00:00          TX          78221
# 2017-12-31 00:00:00+00:00          TX          78231
# 2017-12-31 00:00:00+00:00          TX          78253
# 2017-12-31 00:00:00+00:00          TX          78232
# 2017-12-31 00:00:00+00:00          TX          78231
#
# [913000 rows x 13 columns]

# %% [markdown]
# ---
# ## 4. Add a `month` and `day of week` column to your dataframe, derived from the index using the keywords for those date parts.

# %%
sales["month"] = sales.index.month_name()
sales["weekday"] = sales.index.day_name()
sales.sample(10)
# Out:
#                            sale_amount  sale_id          item_brand  item_id  \
# sale_date
# 2013-04-04 00:00:00+00:00         31.0   328774             Careone       19
# 2017-10-29 00:00:00+00:00         40.0   293923               Ducal       17
# 2013-03-25 00:00:00+00:00          6.0     7388            Riceland        1
# 2013-12-14 00:00:00+00:00          9.0   413024               Reese       23
# 2013-09-03 00:00:00+00:00         45.0    97024        Sally Hansen        6
# 2013-12-15 00:00:00+00:00         13.0   288857          Burts Bees       16
# 2013-05-31 00:00:00+00:00         36.0    98755        Sally Hansen        6
# 2015-06-25 00:00:00+00:00         21.0   283936          Burts Bees       16
# 2013-02-16 00:00:00+00:00         33.0   116911  Twinings Of London        7
# 2015-08-04 00:00:00+00:00         84.0   638220         Natures Way       35
#
#                                                                    item_name  \
# sale_date
# 2013-04-04 00:00:00+00:00                     Careone Family Comb Set - 8 Ct
# 2017-10-29 00:00:00+00:00                            Ducal Refried Red Beans
# 2013-03-25 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-12-14 00:00:00+00:00     Reese Mandarin Oranges Segments In Light Syrup
# 2013-09-03 00:00:00+00:00  Sally Hansen Nail Color Magnetic 903 Silver El...
# 2013-12-15 00:00:00+00:00      Burts Bees Daily Moisturizing Cream Sensitive
# 2013-05-31 00:00:00+00:00  Sally Hansen Nail Color Magnetic 903 Silver El...
# 2015-06-25 00:00:00+00:00      Burts Bees Daily Moisturizing Cream Sensitive
# 2013-02-16 00:00:00+00:00  Twinings Of London Classics Lady Grey Tea - 20 Ct
# 2015-08-04 00:00:00+00:00                     Natures Way Forskohlii - 60 Ct
#
#                            item_price    item_upc12    item_upc14  \
# sale_date
# 2013-04-04 00:00:00+00:00        0.74   41520035646   41520035646
# 2017-10-29 00:00:00+00:00        1.16   88313590791   88313590791
# 2013-03-25 00:00:00+00:00        0.84   35200264013   35200264013
# 2013-12-14 00:00:00+00:00        1.78   70670009658   70670009658
# 2013-09-03 00:00:00+00:00        6.93   74170388732   74170388732
# 2013-12-15 00:00:00+00:00        5.17  792850014008  792850014008
# 2013-05-31 00:00:00+00:00        6.93   74170388732   74170388732
# 2015-06-25 00:00:00+00:00        5.17  792850014008  792850014008
# 2013-02-16 00:00:00+00:00        9.64   70177154004   70177154004
# 2015-08-04 00:00:00+00:00        5.19   33674100066   33674100066
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-04-04 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2017-10-29 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2013-03-25 00:00:00+00:00         1520 Austin Hwy  San Antonio         5
# 2013-12-14 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-09-03 00:00:00+00:00         516 S Flores St  San Antonio         4
# 2013-12-15 00:00:00+00:00      735 SW Military Dr  San Antonio         9
# 2013-05-31 00:00:00+00:00         1520 Austin Hwy  San Antonio         5
# 2015-06-25 00:00:00+00:00      1015 S WW White Rd  San Antonio         6
# 2013-02-16 00:00:00+00:00         1520 Austin Hwy  San Antonio         5
# 2015-08-04 00:00:00+00:00    8503 NW Military Hwy  San Antonio        10
#
#                           store_state  store_zipcode      month   weekday
# sale_date
# 2013-04-04 00:00:00+00:00          TX          78253      April  Thursday
# 2017-10-29 00:00:00+00:00          TX          78253    October    Sunday
# 2013-03-25 00:00:00+00:00          TX          78218      March    Monday
# 2013-12-14 00:00:00+00:00          TX          78217   December  Saturday
# 2013-09-03 00:00:00+00:00          TX          78204  September   Tuesday
# 2013-12-15 00:00:00+00:00          TX          78221   December    Sunday
# 2013-05-31 00:00:00+00:00          TX          78218        May    Friday
# 2015-06-25 00:00:00+00:00          TX          78220       June  Thursday
# 2013-02-16 00:00:00+00:00          TX          78218   February  Saturday
# 2015-08-04 00:00:00+00:00          TX          78231     August   Tuesday

# %% [markdown]
# ---
# ## 5. Add a column to your dataframe, `sales_total`, which is a derived from sale_amount (total items) and item_price.

# %%
sales.rename(columns={"sale_amount": "quantity"}, inplace=True)
sales.head()
# Out:
#                            quantity  sale_id  item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00      13.0        1    Riceland        1
# 2013-01-01 00:00:00+00:00      26.0   211817     Mueller       12
# 2013-01-01 00:00:00+00:00      27.0   832657  Mama Marys       46
# 2013-01-01 00:00:00+00:00      54.0   213643     Mueller       12
# 2013-01-01 00:00:00+00:00      35.0   215469     Mueller       12
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio         8
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio         9
#
#                           store_state  store_zipcode    month  weekday
# sale_date
# 2013-01-01 00:00:00+00:00          TX          78253  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78217  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78217  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78232  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78221  January  Tuesday

# %%
sales["sale_amount"] = sales.quantity * sales.item_price
sales.head()
# Out:
#                            quantity  sale_id  item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00      13.0        1    Riceland        1
# 2013-01-01 00:00:00+00:00      26.0   211817     Mueller       12
# 2013-01-01 00:00:00+00:00      27.0   832657  Mama Marys       46
# 2013-01-01 00:00:00+00:00      54.0   213643     Mueller       12
# 2013-01-01 00:00:00+00:00      35.0   215469     Mueller       12
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio         8
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio         9
#
#                           store_state  store_zipcode    month  weekday  \
# sale_date
# 2013-01-01 00:00:00+00:00          TX          78253  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78217  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78217  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78232  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78221  January  Tuesday
#
#                            sale_amount
# sale_date
# 2013-01-01 00:00:00+00:00        10.92
# 2013-01-01 00:00:00+00:00       218.40
# 2013-01-01 00:00:00+00:00       125.55
# 2013-01-01 00:00:00+00:00       453.60
# 2013-01-01 00:00:00+00:00       294.00

# %% [markdown]
# ---
# ## 6. Using pandas.DataFrame.diff() function, create a new column that is the result of the current sales - the previous days sales.

# %%
sales["diff(1)"] = sales.sale_amount.diff(1)
sales.head()
# Out:
#                            quantity  sale_id  item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00      13.0        1    Riceland        1
# 2013-01-01 00:00:00+00:00      26.0   211817     Mueller       12
# 2013-01-01 00:00:00+00:00      27.0   832657  Mama Marys       46
# 2013-01-01 00:00:00+00:00      54.0   213643     Mueller       12
# 2013-01-01 00:00:00+00:00      35.0   215469     Mueller       12
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio         8
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio         9
#
#                           store_state  store_zipcode    month  weekday  \
# sale_date
# 2013-01-01 00:00:00+00:00          TX          78253  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78217  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78217  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78232  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78221  January  Tuesday
#
#                            sale_amount  diff(1)
# sale_date
# 2013-01-01 00:00:00+00:00        10.92      NaN
# 2013-01-01 00:00:00+00:00       218.40   207.48
# 2013-01-01 00:00:00+00:00       125.55   -92.85
# 2013-01-01 00:00:00+00:00       453.60   328.05
# 2013-01-01 00:00:00+00:00       294.00  -159.60

# %% [markdown]
# ---
# ## 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
sales = ac.get_sales()
sales = pr.prep_sales(sales)
sales.head()
# Out:
#                            quantity  sale_id  item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00      13.0        1    Riceland        1
# 2013-01-01 00:00:00+00:00      26.0   211817     Mueller       12
# 2013-01-01 00:00:00+00:00      27.0   832657  Mama Marys       46
# 2013-01-01 00:00:00+00:00      54.0   213643     Mueller       12
# 2013-01-01 00:00:00+00:00      35.0   215469     Mueller       12
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
#
#                                     store_address   store_city  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio         1
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio         7
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio         8
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio         9
#
#                           store_state  store_zipcode    month  weekday  \
# sale_date
# 2013-01-01 00:00:00+00:00          TX          78253  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78217  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78217  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78232  January  Tuesday
# 2013-01-01 00:00:00+00:00          TX          78221  January  Tuesday
#
#                            sale_amount  diff(1)
# sale_date
# 2013-01-01 00:00:00+00:00        10.92      NaN
# 2013-01-01 00:00:00+00:00       218.40   207.48
# 2013-01-01 00:00:00+00:00       125.55   -92.85
# 2013-01-01 00:00:00+00:00       453.60   328.05
# 2013-01-01 00:00:00+00:00       294.00  -159.60

# %% [markdown]
# ---
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %% [markdown]
# ## 1. Convert date column to datetime format.

# %%
germany = ac.get_germany()
germany.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
# Date           4383 non-null object
# Consumption    4383 non-null float64
# Wind           2920 non-null float64
# Solar          2188 non-null float64
# Wind+Solar     2187 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 205.5+ KB

# %%
germany["Date"] = pd.to_datetime(germany.Date)
germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
# Date           4383 non-null datetime64[ns]
# Consumption    4383 non-null float64
# Wind           2920 non-null float64
# Solar          2188 non-null float64
# Wind+Solar     2187 non-null float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 205.5 KB

# %% [markdown]
# ---
# ## 2. Plot the distribution of each of your variables.

# %%
germany.hist(figsize=(16, 16))
plt.show()

# %% [markdown]
# ---
# ## 3. Set the index to be the datetime variable.

# %%
germany = germany.sort_values("Date").set_index("Date")
germany
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %% [markdown]
# ---
# ## 4. Add a `month` and a `year` column to your dataframe.

# %%
germany["month"] = germany.index.month_name()
germany["year"] = germany.index.year

# %%
germany
# Out:
#             Consumption     Wind   Solar  Wind+Solar     month  year
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN   January  2006
# 2006-01-02   1380.52100      NaN     NaN         NaN   January  2006
# 2006-01-03   1442.53300      NaN     NaN         NaN   January  2006
# 2006-01-04   1457.21700      NaN     NaN         NaN   January  2006
# 2006-01-05   1477.13100      NaN     NaN         NaN   January  2006
# ...                 ...      ...     ...         ...       ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586  December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131  December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714  December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156  December  2017
#
# [4383 rows x 6 columns]

# %% [markdown]
# ---
# ## 5. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
germany = ac.get_germany()
germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
# Date           4383 non-null object
# Consumption    4383 non-null float64
# Wind           2920 non-null float64
# Solar          2188 non-null float64
# Wind+Solar     2187 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 205.5+ KB

# %%
def convert_date_dtype(df):
    """
    This function converts the Date dtype from an object to datetime
    """
    
    df["Date"] = pd.to_datetime(df.Date)
    
    return df

# %%
germany = convert_date_dtype(germany)
germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
# Date           4383 non-null datetime64[ns]
# Consumption    4383 non-null float64
# Wind           2920 non-null float64
# Solar          2188 non-null float64
# Wind+Solar     2187 non-null float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 205.5 KB

# %%
def plot_dist(df):
    """
    This function plots the distributions of each variable from the DataFrame passed into the function
    """
    
    df.hist(figsize=(16, 16))
    plt.show()

# %%
plot_dist(germany)

# %%
def set_date_index(df):
    """
    This function sorts the Date field and sets it as the index of the DataFrame passed into the function
    """
    
    df = df.sort_values("Date").set_index("Date")
    
    return df

# %%
germany = set_date_index(germany)
germany.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
def make_new_variables(df):
    """
    This function makes a month and year variable in the DataFrame passed into the function
    """
    
    df["month"] = df.index.month_name()
    df["year"] = df.index.year
    
    return df

# %%
germany = make_new_variables(germany)
germany
# Out:
#             Consumption     Wind   Solar  Wind+Solar     month  year
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN   January  2006
# 2006-01-02   1380.52100      NaN     NaN         NaN   January  2006
# 2006-01-03   1442.53300      NaN     NaN         NaN   January  2006
# 2006-01-04   1457.21700      NaN     NaN         NaN   January  2006
# 2006-01-05   1477.13100      NaN     NaN         NaN   January  2006
# ...                 ...      ...     ...         ...       ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586  December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131  December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714  December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156  December  2017
#
# [4383 rows x 6 columns]

# %%
germany = ac.get_germany()
germany = pr.prep_germany(germany)
germany
# Out:
#             Consumption     Wind   Solar  Wind+Solar     month  year
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN   January  2006
# 2006-01-02   1380.52100      NaN     NaN         NaN   January  2006
# 2006-01-03   1442.53300      NaN     NaN         NaN   January  2006
# 2006-01-04   1457.21700      NaN     NaN         NaN   January  2006
# 2006-01-05   1477.13100      NaN     NaN         NaN   January  2006
# ...                 ...      ...     ...         ...       ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586  December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131  December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714  December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156  December  2017
#
# [4383 rows x 6 columns]

# %% [markdown]
# ---
# ## Install and use the vega_datasets for the next exercise
# For the datasets below, examine the data types of each column, ensure that the dates are in the proper format, and set the dataframe's index to the date column as appropriate.

# %%
from vega_datasets import data
temps = data.sf_temps()
temps
# Out:
#       temp                date
# 0     47.8 2010-01-01 00:00:00
# 1     47.4 2010-01-01 01:00:00
# 2     46.9 2010-01-01 02:00:00
# 3     46.5 2010-01-01 03:00:00
# 4     46.0 2010-01-01 04:00:00
# ...    ...                 ...
# 8754  50.4 2010-12-31 19:00:00
# 8755  49.9 2010-12-31 20:00:00
# 8756  49.4 2010-12-31 21:00:00
# 8757  48.8 2010-12-31 22:00:00
# 8758  48.3 2010-12-31 23:00:00
#
# [8759 rows x 2 columns]

# %% [markdown]
# Use the above dataset for the exercises below:

# %% [markdown]
# ---
# ## 1. Resample by the day and take the average temperature. Visualize the average temperature over time.

# %%
temps = temps.sort_values("date").set_index("date")
temps
# Out:
#                      temp
# date
# 2010-01-01 00:00:00  47.8
# 2010-01-01 01:00:00  47.4
# 2010-01-01 02:00:00  46.9
# 2010-01-01 03:00:00  46.5
# 2010-01-01 04:00:00  46.0
# ...                   ...
# 2010-12-31 19:00:00  50.4
# 2010-12-31 20:00:00  49.9
# 2010-12-31 21:00:00  49.4
# 2010-12-31 22:00:00  48.8
# 2010-12-31 23:00:00  48.3
#
# [8759 rows x 1 columns]

# %%
avg_temps = pd.DataFrame(temps.temp.resample("D").mean())
avg_temps
# Out:
#                  temp
# date
# 2010-01-01  49.170833
# 2010-01-02  49.304167
# 2010-01-03  49.391667
# 2010-01-04  49.445833
# 2010-01-05  49.491667
# ...               ...
# 2010-12-27  48.991667
# 2010-12-28  49.000000
# 2010-12-29  49.012500
# 2010-12-30  49.012500
# 2010-12-31  49.116667
#
# [365 rows x 1 columns]

# %%
plt.figure(figsize=(16, 8))

plt.plot(avg_temps.temp, label="Mean")
plt.title("Temperatures Over Time")
plt.xlabel("Date")
plt.ylabel("Degrees")
plt.show()

# %% [markdown]
# ---
# ## 2. Write the code necessary to visualize the minimum temperature over time.

# %%
min_temps = pd.DataFrame(temps.temp.resample("D").min())
min_temps
# Out:
#             temp
# date
# 2010-01-01  45.8
# 2010-01-02  46.0
# 2010-01-03  46.1
# 2010-01-04  46.1
# 2010-01-05  46.1
# ...          ...
# 2010-12-27  45.6
# 2010-12-28  45.6
# 2010-12-29  45.6
# 2010-12-30  45.6
# 2010-12-31  45.8
#
# [365 rows x 1 columns]

# %%
plt.figure(figsize=(16, 8))

plt.plot(avg_temps.temp, label="Mean Temps")
plt.plot(min_temps.temp, label="Min Temps")
plt.title("Temperatures Over Time")
plt.xlabel("Date")
plt.ylabel("Degrees")
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 3. Write the code necessary to visualize the maximum temperature over time.

# %%
max_temps = pd.DataFrame(temps.temp.resample("D").max())
max_temps
# Out:
#             temp
# date
# 2010-01-01  53.3
# 2010-01-02  53.4
# 2010-01-03  53.5
# 2010-01-04  53.6
# 2010-01-05  53.8
# ...          ...
# 2010-12-27  53.2
# 2010-12-28  53.2
# 2010-12-29  53.2
# 2010-12-30  53.2
# 2010-12-31  53.2
#
# [365 rows x 1 columns]

# %%
plt.figure(figsize=(16, 8))

plt.plot(avg_temps.temp, label="Mean Temps")
plt.plot(min_temps.temp, label="Min Temps")
plt.plot(max_temps.temp, label="Max Temps")
plt.title("Temperatures Over Time")
plt.xlabel("Date")
plt.ylabel("Degrees")
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 4. Which month is the coldest, on average?

# %%
temps
# Out:
#                      temp
# date
# 2010-01-01 00:00:00  47.8
# 2010-01-01 01:00:00  47.4
# 2010-01-01 02:00:00  46.9
# 2010-01-01 03:00:00  46.5
# 2010-01-01 04:00:00  46.0
# ...                   ...
# 2010-12-31 19:00:00  50.4
# 2010-12-31 20:00:00  49.9
# 2010-12-31 21:00:00  49.4
# 2010-12-31 22:00:00  48.8
# 2010-12-31 23:00:00  48.3
#
# [8759 rows x 1 columns]

# %%
mo_avg_temps = pd.DataFrame(temps.temp.resample("M").mean())
mo_avg_temps["month"] = mo_avg_temps.index.month_name()
mo_avg_temps.sort_values("temp").head(1)["month"]
# Out:
# date
# 2010-01-31    January
# Name: month, dtype: object

# %% [markdown]
# ---
# ## 5. Which month has the highest average temperature?

# %%
mo_avg_temps.sort_values("temp", ascending=False).head(1)["month"]
# Out:
# date
# 2010-09-30    September
# Name: month, dtype: object

# %% [markdown]
# ---
# ## 6. Resample by the day and calculate the min and max temp for the day (Hint: `.agg(['min', 'max'])`). Use this resampled dataframe to calculate the change in temperature for the day. Which month has the highest daily temperature variability?

# %%
min_max_temps = temps.temp.resample("D").agg(["min", "max"])
min_max_temps
# Out:
#              min   max
# date
# 2010-01-01  45.8  53.3
# 2010-01-02  46.0  53.4
# 2010-01-03  46.1  53.5
# 2010-01-04  46.1  53.6
# 2010-01-05  46.1  53.8
# ...          ...   ...
# 2010-12-27  45.6  53.2
# 2010-12-28  45.6  53.2
# 2010-12-29  45.6  53.2
# 2010-12-30  45.6  53.2
# 2010-12-31  45.8  53.2
#
# [365 rows x 2 columns]

# %%
min_max_temps["delta"] = min_max_temps["max"] - min_max_temps["min"]
min_max_temps
# Out:
#              min   max  delta
# date
# 2010-01-01  45.8  53.3    7.5
# 2010-01-02  46.0  53.4    7.4
# 2010-01-03  46.1  53.5    7.4
# 2010-01-04  46.1  53.6    7.5
# 2010-01-05  46.1  53.8    7.7
# ...          ...   ...    ...
# 2010-12-27  45.6  53.2    7.6
# 2010-12-28  45.6  53.2    7.6
# 2010-12-29  45.6  53.2    7.6
# 2010-12-30  45.6  53.2    7.6
# 2010-12-31  45.8  53.2    7.4
#
# [365 rows x 3 columns]

# %%
min_max_mo_temps = pd.DataFrame(min_max_temps.delta.resample("M").max())
min_max_mo_temps["month"] = min_max_mo_temps.index.month_name()
min_max_mo_temps
# Out:
#             delta      month
# date
# 2010-01-31    9.3    January
# 2010-02-28    9.9   February
# 2010-03-31   12.0      March
# 2010-04-30   13.0      April
# 2010-05-31   13.1        May
# 2010-06-30   14.8       June
# 2010-07-31   14.8       July
# 2010-08-31   15.0     August
# 2010-09-30   14.9  September
# 2010-10-31   14.4    October
# 2010-11-30   11.8   November
# 2010-12-31    8.9   December

# %%
min_max_mo_temps.sort_values("delta", ascending=False).head(1)["month"]
# Out:
# date
# 2010-08-31    August
# Name: month, dtype: object

# %% [markdown]
# ---
# ## 7. **Bonus**: Visualize the daily min, average, and max temperature over time on a single line plot, i.e. the min, average, and maximum temperature should be 3 seperate lines.
# See exercise #3

# %% [markdown]
# ---
# Use the Vega_Datasets to work with the flights_20k data

# %% [markdown]
# ---
# ## 1. Convert any negative delays to 0.

# %%
flights = data.flights_20k()
flights
# Out:
#                      date  delay  distance origin destination
# 0     2001-01-13 14:56:00     32       417    SAN         SJC
# 1     2001-01-31 16:40:00     -5      1093    FLL         ISP
# 2     2001-02-11 18:39:00      3       293    LBB         DAL
# 3     2001-01-10 21:00:00    -15       550    MSY         MCO
# 4     2001-03-30 21:45:00     -2       229    STL         IND
# ...                   ...    ...       ...    ...         ...
# 19995 2001-03-22 15:10:00      4       446    SAN         OAK
# 19996 2001-01-19 13:05:00     -6      1489    SEA         MCI
# 19997 2001-02-07 11:37:00    -16      1848    MCO         PHX
# 19998 2001-02-24 16:50:00     42       443    RDU         BNA
# 19999 2001-03-14 11:33:00      0       328    ABQ         PHX
#
# [20000 rows x 5 columns]

# %%
flights["delay"] = np.where(flights.delay < 0, 0, flights.delay)
flights
# Out:
#                      date  delay  distance origin destination
# 0     2001-01-13 14:56:00     32       417    SAN         SJC
# 1     2001-01-31 16:40:00      0      1093    FLL         ISP
# 2     2001-02-11 18:39:00      3       293    LBB         DAL
# 3     2001-01-10 21:00:00      0       550    MSY         MCO
# 4     2001-03-30 21:45:00      0       229    STL         IND
# ...                   ...    ...       ...    ...         ...
# 19995 2001-03-22 15:10:00      4       446    SAN         OAK
# 19996 2001-01-19 13:05:00      0      1489    SEA         MCI
# 19997 2001-02-07 11:37:00      0      1848    MCO         PHX
# 19998 2001-02-24 16:50:00     42       443    RDU         BNA
# 19999 2001-03-14 11:33:00      0       328    ABQ         PHX
#
# [20000 rows x 5 columns]

# %% [markdown]
# ---
# ## 2. Which hour of the day has the highest average delay?

# %%
flights = flights.set_index("date")
flights
# Out:
#                      delay  distance origin destination
# date
# 2001-01-13 14:56:00     32       417    SAN         SJC
# 2001-01-31 16:40:00      0      1093    FLL         ISP
# 2001-02-11 18:39:00      3       293    LBB         DAL
# 2001-01-10 21:00:00      0       550    MSY         MCO
# 2001-03-30 21:45:00      0       229    STL         IND
# ...                    ...       ...    ...         ...
# 2001-03-22 15:10:00      4       446    SAN         OAK
# 2001-01-19 13:05:00      0      1489    SEA         MCI
# 2001-02-07 11:37:00      0      1848    MCO         PHX
# 2001-02-24 16:50:00     42       443    RDU         BNA
# 2001-03-14 11:33:00      0       328    ABQ         PHX
#
# [20000 rows x 4 columns]

# %%
mean_hourly_delays = pd.DataFrame(flights.delay.resample("H").mean())
mean_hourly_delays["hour"] = mean_hourly_delays.index.hour
mean_hourly_delays
# Out:
#                          delay  hour
# date
# 2001-01-01 00:00:00  14.000000     0
# 2001-01-01 01:00:00        NaN     1
# 2001-01-01 02:00:00        NaN     2
# 2001-01-01 03:00:00        NaN     3
# 2001-01-01 04:00:00        NaN     4
# ...                        ...   ...
# 2001-03-31 17:00:00  11.666667    17
# 2001-03-31 18:00:00  12.538462    18
# 2001-03-31 19:00:00  22.125000    19
# 2001-03-31 20:00:00  27.600000    20
# 2001-03-31 21:00:00  11.200000    21
#
# [2158 rows x 2 columns]

# %%
mean_hourly_delays.groupby("hour").delay.max().sort_values(ascending=False).head(1)
# Out:
# hour
# 3    360.0
# Name: delay, dtype: float64

# %% [markdown]
# ---
# ## 3. Does the day of the week make a difference in the delay amount?

# %%
flights
# Out:
#                      delay  distance origin destination
# date
# 2001-01-13 14:56:00     32       417    SAN         SJC
# 2001-01-31 16:40:00      0      1093    FLL         ISP
# 2001-02-11 18:39:00      3       293    LBB         DAL
# 2001-01-10 21:00:00      0       550    MSY         MCO
# 2001-03-30 21:45:00      0       229    STL         IND
# ...                    ...       ...    ...         ...
# 2001-03-22 15:10:00      4       446    SAN         OAK
# 2001-01-19 13:05:00      0      1489    SEA         MCI
# 2001-02-07 11:37:00      0      1848    MCO         PHX
# 2001-02-24 16:50:00     42       443    RDU         BNA
# 2001-03-14 11:33:00      0       328    ABQ         PHX
#
# [20000 rows x 4 columns]

# %%
flights["weekday"] = flights.index.day_name()
flights
# Out:
#                      delay  distance origin destination    weekday
# date
# 2001-01-13 14:56:00     32       417    SAN         SJC   Saturday
# 2001-01-31 16:40:00      0      1093    FLL         ISP  Wednesday
# 2001-02-11 18:39:00      3       293    LBB         DAL     Sunday
# 2001-01-10 21:00:00      0       550    MSY         MCO  Wednesday
# 2001-03-30 21:45:00      0       229    STL         IND     Friday
# ...                    ...       ...    ...         ...        ...
# 2001-03-22 15:10:00      4       446    SAN         OAK   Thursday
# 2001-01-19 13:05:00      0      1489    SEA         MCI     Friday
# 2001-02-07 11:37:00      0      1848    MCO         PHX  Wednesday
# 2001-02-24 16:50:00     42       443    RDU         BNA   Saturday
# 2001-03-14 11:33:00      0       328    ABQ         PHX  Wednesday
#
# [20000 rows x 5 columns]

# %%
flights.groupby("weekday").delay.sum().sort_values(ascending=False)
# Out:
# weekday
# Friday       53770
# Thursday     38605
# Wednesday    33969
# Tuesday      27715
# Sunday       27221
# Monday       21354
# Saturday     19755
# Name: delay, dtype: int64

# %% [markdown]
# ---
# ## 4. Does the month make a difference in the delay amount?

# %%
flights['month'] = flights.index.month_name()
flights
# Out:
#                      delay  distance origin destination    weekday     month
# date
# 2001-01-13 14:56:00     32       417    SAN         SJC   Saturday   January
# 2001-01-31 16:40:00      0      1093    FLL         ISP  Wednesday   January
# 2001-02-11 18:39:00      3       293    LBB         DAL     Sunday  February
# 2001-01-10 21:00:00      0       550    MSY         MCO  Wednesday   January
# 2001-03-30 21:45:00      0       229    STL         IND     Friday     March
# ...                    ...       ...    ...         ...        ...       ...
# 2001-03-22 15:10:00      4       446    SAN         OAK   Thursday     March
# 2001-01-19 13:05:00      0      1489    SEA         MCI     Friday   January
# 2001-02-07 11:37:00      0      1848    MCO         PHX  Wednesday  February
# 2001-02-24 16:50:00     42       443    RDU         BNA   Saturday  February
# 2001-03-14 11:33:00      0       328    ABQ         PHX  Wednesday     March
#
# [20000 rows x 6 columns]

# %%
flights.groupby("month").delay.sum().sort_values(ascending=False)
# Out:
# month
# February    76987
# January     76670
# March       68732
# Name: delay, dtype: int64
