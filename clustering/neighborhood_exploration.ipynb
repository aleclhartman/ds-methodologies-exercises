# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

from sklearn.preprocessing import MinMaxScaler

pd.set_option("display.max_columns", None)

import warnings
warnings.filterwarnings("ignore")

from env import user, host, password, get_db_url
import wrangle_zillow as wr

# %%
query = """SELECT latitude, longitude, regionidneighborhood
FROM properties_2017"""

url = get_db_url("zillow")

# %%
hoods = pd.read_sql(query, url)

# %%
hoods.dropna(inplace=True)

# %%
hoods = hoods[hoods.regionidneighborhood <= 50000]

# %%
hoods.shape
# Out:
# (364362, 3)

# %%
plt.figure(figsize=(16, 10))
sns.scatterplot(data=hoods.sample(1000), y='latitude', x='longitude', hue='regionidneighborhood')
