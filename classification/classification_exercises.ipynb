# %%
import numpy as np
import pandas as pd

from pydataset import data

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.

# %%
df_iris = data("iris")

# %%
# print the first 3 rows
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
# print the number of rows and columns (shape)
df_iris.shape
# Out:
# (150, 5)

# %%
# print the column names
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
# print the data type of each column
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
# Sepal.Length    150 non-null float64
# Sepal.Width     150 non-null float64
# Petal.Length    150 non-null float64
# Petal.Width     150 non-null float64
# Species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
# print the summary statistics for each of the numeric variables.
# Would you recommend rescaling the data based on these statistics?
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ---
# ### 2. Read Table1_CustDetails the excel module dataset, Excel_Exercises.xlsx, into a dataframe, df_excel

# %%
df_excel = pd.read_excel("/Users/alechartman/codeup-data-science/ds-methodologies-exercises/classification/Spreadsheets_Exercises.xlsx", sheet_name="Table1_CustDetails")
df_excel
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
# assign the first 100 rows to a new dataframe, df_excel_sample
df_excel_sample = df_excel.head(100)
df_excel_sample
# Out:
#    customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0   0002-ORFBO  Female                  0     Yes        Yes              1
# 1   0003-MKNFE    Male                  0      No         No              2
# 2   0004-TLHLJ    Male                  0      No         No              1
# 3   0011-IGKFF    Male                  1     Yes         No              1
# 4   0013-EXCHZ  Female                  1     Yes         No              1
# 5   0013-MHZWF  Female                  0      No        Yes              1
# 6   0013-SMEOE  Female                  1     Yes         No              1
# 7   0014-BMAQU    Male                  0     Yes         No              2
# 8   0015-UOCOJ  Female                  1      No         No              1
# 9   0016-QLJIS  Female                  0     Yes        Yes              2
# 10  0017-DINOC    Male                  0      No         No              0
# ...

# %%
# print the number of rows of your original dataframe
df_excel.shape[0]
# Out:
# 7049

# %%
# print the first 5 column names
df_excel.columns[:5]
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents'], dtype='object')

# %%
# print the column names that have a data type of object
[column for column in df_excel if (df_excel[column].dtypes == "object")]
# Out:
# ['customer_id', 'gender', 'partner', 'dependents', 'payment_type', 'churn']

# %%
df_excel.select_dtypes(object).columns
# Out:
# Index(['customer_id', 'gender', 'partner', 'dependents', 'payment_type',
#        'churn'],
#       dtype='object')

# %%
# compute the range for each of the numeric variables.
[(column, df_excel[column].min(), df_excel[column].max()) for column in df_excel if (df_excel[column].dtypes == "int64" or df_excel[column].dtypes == "float64")]
# Out:
# [('is_senior_citizen', 0, 1),
#  ('phone_service', 0, 2),
#  ('internet_service', 0, 2),
#  ('contract_type', 0, 2),
#  ('monthly_charges', 18.25, 118.75),
#  ('total_charges', 18.8, 8684.8)]

# %% [markdown]
# ---
# ### 3. Read the data from this google sheet into a dataframe, df_google

# %%
sheet_url = "https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357"

csv_export_url = sheet_url.replace("/edit#gid=", "/export?format=csv&gid=")

df_google = pd.read_csv(csv_export_url)
df_google.drop(columns=["PassengerId"], inplace=True)
df_google
# Out:
#      Survived  Pclass                                                 Name  \
# 0           0       3                              Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# 2           1       3                               Heikkinen, Miss. Laina
# 3           1       1         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                             Allen, Mr. William Henry
# ..        ...     ...                                                  ...
# 886         0       2                                Montvila, Rev. Juozas
# 887         1       1                         Graham, Miss. Margaret Edith
# 888         0       3             Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                                Behr, Mr. Karl Howell
# 890         0       3                                  Dooley, Mr. Patrick
#
# ...

# %%
# print the first 3 rows
df_google.head(3)
# Out:
#    Survived  Pclass                                                 Name  \
# 0         0       3                              Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# 2         1       3                               Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# print the number of rows and columns
df_google.shape
# Out:
# (891, 11)

# %%
# print the column names
df_google.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# print the data type of each column
df_google.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
# print the summary statistics for each of the numeric variables
df_google.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# print the unique values for each of your categorical variables
print(f"Survived unique values {np.sort(df_google.Survived.unique())}")
print(f"Pclass unique values {np.sort(df_google.Pclass.unique())}")
print(f"Sex unique values {np.sort(df_google.Sex.unique())}")
print(f"SibSp unique values {np.sort(df_google.SibSp.unique())}")
print(f"Parch unique values {np.sort(df_google.Parch.unique())}")
print(f"Embarked unique values {df_google.Embarked.unique()}")
# Out:
# Survived unique values [0 1]
# Pclass unique values [1 2 3]
# Sex unique values ['female' 'male']
# SibSp unique values [0 1 2 3 4 5 8]
# Parch unique values [0 1 2 3 4 5 6]
# Embarked unique values ['S' 'C' 'Q' nan]

# %% [markdown]
# ### In a new python module, acquire.py

# %%
import acquire as ac

# %%
# 1. get_titanic_data: returns the titanic data from the codeup data
# science database as a pandas data frame.
titanic = ac.get_titanic_data()
titanic
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# ...

# %%
# 2. get_iris_data: returns the data from the iris_db on the codeup
# data science database as a pandas data frame. The returned data
# frame should include the actual name of the species in addition
# to the species_ids.
iris = ac.get_iris_data()
iris.head()
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
# 3               4           4.6          3.1           1.5          0.2
# 4               5           5.0          3.6           1.4          0.2
#
#    species_id species_name
# 0           1       setosa
# 1           1       setosa
# 2           1       setosa
# 3           1       setosa
# 4           1       setosa

# %% [markdown]
# ---
# # Exploratory Data Analysis Exercises
# Continue in your classification_exercises.ipynb notebook. Use the iris dataset.

# %% [markdown]
# #### Objectives of Exploring
#
# - Find the best predictors
# - Explore derived/synthetic column combinations
# - We're looking for signal vs. noise
# - Produces good insights for your deliverables and MVP

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import prepare as pr

# %%
df = ac.get_iris_data()
df.head()
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
# 3               4           4.6          3.1           1.5          0.2
# 4               5           5.0          3.6           1.4          0.2
#
#    species_id species_name
# 0           1       setosa
# 1           1       setosa
# 2           1       setosa
# 3           1       setosa
# 4           1       setosa

# %%
# df = pr.drop_iris_columns(df)

# %%
# df = pr.rename_iris_columns(df)

# %%
# df.head()

# %% [markdown]
# ### 1. Split data into train (70%) & test (30%) samples.

# %%
encode, train, test = pr.prep_iris(df)

# %%
train.shape
# Out:
# (120, 6)

# %%
test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 60            5.0          2.0           3.5          1.0        1
# 36            5.5          3.5           1.3          0.2        0
# 127           6.1          3.0           4.9          1.8        2
# 145           6.7          3.0           5.2          2.3        2
# 41            4.5          2.3           1.3          0.3        0

# %% [markdown]
# ### 2. Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis is the variable name, the y-axis is the measure. Add another dimension using color to represent species. Document takeaways from this visualization.

# %% [markdown]
# #### pd.melt Notes:
#
# - Transforms a wide DataFrame into a long DataFrame
# - pd.melt(df, ["column_to_keep"], var_name="new_name_for_key")
#     - key is the name of the original column name
# - After melting, each row is a singular measurement for the index

# %%
melt_df = pd.melt(train[["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]], "species", var_name="measurement")
melt_df
# Out:
#         species   measurement  value
# 0        setosa  sepal_length    4.4
# 1    versicolor  sepal_length    6.1
# 2     virginica  sepal_length    5.7
# 3        setosa  sepal_length    5.4
# 4        setosa  sepal_length    4.7
# ..          ...           ...    ...
# 475  versicolor   petal_width    1.3
# 476  versicolor   petal_width    1.0
# 477  versicolor   petal_width    1.3
# 478      setosa   petal_width    0.3
# 479   virginica   petal_width    2.4
#
# [480 rows x 3 columns]

# %%
plt.rc("figure", figsize=(14, 8))
plt.rc("font", size=13)

# %%
sns.swarmplot(x="measurement", y="value", hue="species", data=melt_df)
plt.show()

# %% [markdown]
# Takeaways:
#
# - petal_length and petal_width for setosa is distinctly lower than that of the other species
# - virginica's petals are consistently longer and wider than any other species' petals
# - versicolor's petals are consistently in the middle of the pack when comparing against other species
# - species is indeterminable solely using sepal_width

# %% [markdown]
# ### 3. Create 4 subplots (2 rows x 2 columns) of scatterplots
# - sepal_length x sepal_width
# - petal_length x petal_width
# - sepal_area x petal_area
# - sepal_length x petal_length
# - Make your figure size 14 x 8.
# - What are your takeaways?

# %%
train["sepal_area"] = train.sepal_length * train.sepal_width
train["petal_area"] = train.petal_length * train.petal_width
train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 8             4.4          2.9           1.4          0.2      setosa
# 73            6.1          2.8           4.7          1.2  versicolor
# 113           5.7          2.5           5.0          2.0   virginica
# 31            5.4          3.4           1.5          0.4      setosa
# 29            4.7          3.2           1.6          0.2      setosa
#
#      species_encoded  sepal_area  petal_area
# 8                  0       12.76        0.28
# 73                 1       17.08        5.64
# 113                2       14.25       10.00
# 31                 0       18.36        0.60
# 29                 0       15.04        0.32

# %%
fig, axs = plt.subplots(2, 2)
plt.subplots_adjust(hspace=.6)

plt.suptitle("Scatterplots")

axs[0, 0].set(title="Sepal Length & Width", xlabel="Sepal Length", ylabel="Sepal Width")
axs[0, 0].scatter(x=train.sepal_length,  y=train.sepal_width, label=train.species)

axs[0, 1].set(title="Petal Length & Width", xlabel="Petal Length", ylabel="Petal Width")
axs[0, 1].scatter(x=train.petal_length,  y=train.petal_width, label=train.species)

axs[1, 0].set(title="Sepal & Petal Area", xlabel="Sepal Area", ylabel="Petal Area")
axs[1, 0].scatter(x=train.sepal_area,  y=train.petal_area, label=train.species)

axs[1, 1].set(title="Sepal & Petal Length", xlabel="Sepal Length", ylabel="Petal Length")
axs[1, 1].scatter(x=train.sepal_length, y=train.petal_length, label=train.species)

plt.show()

# %%
plt.subplots_adjust(hspace=.6)

plt.suptitle("Scatterplots")

plt.subplot(2, 2, 1)
plt.title("Sepal Length & Width")
sns.scatterplot(x=train.sepal_length,  y=train.sepal_width, hue=train.species, legend=False)

plt.subplot(2, 2, 2)
plt.title("Petal Length & Width")
sns.scatterplot(x=train.petal_length,  y=train.petal_width, hue=train.species)
plt.legend()

plt.subplot(2, 2, 3)
plt.title("Sepal & Petal Area")
sns.scatterplot(x=train.sepal_area,  y=train.petal_area, hue=train.species, legend=False)

plt.subplot(2, 2, 4)
plt.title("Sepal & Petal Length")
sns.scatterplot(x=train.sepal_length, y=train.petal_length, hue=train.species, legend=False)

plt.show()

# %% [markdown]
# Takeaways:
#
# - Petal length and width seem to have a positive linear relationship
# - Sepal and petal area may have a positive linear relationship
# - Sepal and petal length may have a positive linear relationship
# - Area plot and petal_length & petal_widthare the best indicators

# %% [markdown]
# ### 4. Create a heatmap of each variable layering correlation coefficient on top.
# - we use heatmaps with linear correlation to find features that correlate well with the target variable
# - with calssification, our target var is discrete be it's a class/category
# - Our heatmap helps identify which input features correlate with each other
# - why is that important? some/many classification algorithms mathematically assume independence of features
# - For example, I would avoid petal_area, petal_length, and petal_width if I were doing a naive bayes model
# - Create new features using highly correlated features such as petal_area in this exercise

# %% [markdown]
# #### Looking for best predictors
# - often times we want features that do not correlate with one another

# %%
train.corr()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width  \
# sepal_length         1.000000    -0.146671      0.882457     0.822223
# sepal_width         -0.146671     1.000000     -0.439733    -0.386133
# petal_length         0.882457    -0.439733      1.000000     0.963236
# petal_width          0.822223    -0.386133      0.963236     1.000000
# species_encoded      0.782352    -0.453113      0.948223     0.959644
# sepal_area           0.706372     0.590575      0.413662     0.406688
# petal_area           0.863244    -0.306389      0.959595     0.979605
#
#                  species_encoded  sepal_area  petal_area
# sepal_length            0.782352    0.706372    0.863244
# sepal_width            -0.453113    0.590575   -0.306389
# petal_length            0.948223    0.413662    0.959595
# petal_width             0.959644    0.406688    0.979605
# species_encoded         1.000000    0.325754    0.952187
# sepal_area              0.325754    1.000000    0.493948
# ...

# %%
sns.heatmap(train.drop(columns="species_encoded").corr(), annot=True, cmap="coolwarm_r", vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ### 5. Create a scatter matrix visualizing the interaction of each variable

# %%
sns.pairplot(data=train.drop(columns="species_encoded"), hue="species")
plt.show()

# %% [markdown]
# ### 6. Is the sepal length significantly different in virginica compared to versicolor? Run an experiment to test this.
#
# #### Hypotheses
#
# $H_0$: The difference in sepal length between virginica and versicolor is insignificant
#
# $H_a$: The difference in sepal length between virginica and versicolor is significant

# %%
from scipy import stats

# %%
alpha = .001

virginica = train[train.species == "virginica"].sepal_length
versicolor = train[train.species == "versicolor"].sepal_length

tstat, p = stats.ttest_ind(virginica, versicolor)
print(f"t = {tstat:.3f}")
print(f"p = {p}")

if p < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# t = 4.669
# p = 1.23772755885435e-05
# Reject null hypothesis

# %% [markdown]
# > We should hold onto the sepal_length feature for further analysis as the differences between the virginica and versicolor is significant.
